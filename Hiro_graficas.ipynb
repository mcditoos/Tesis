# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %%
from sympy import *

# %%
init_printing(use_unicode=True)
N, n,t = symbols('N  n wt  ')

# %%
alpha =pi/(2*N)

# %%
B=Matrix([[cos(alpha),1j*sin(alpha)],[1j*sin(alpha),cos(alpha)]])
B
# Out:
# ⎡      ⎛ π ⎞              ⎛ π ⎞⎤
# ⎢   cos⎜───⎟     1.0⋅ⅈ⋅sin⎜───⎟⎥
# ⎢      ⎝2⋅N⎠              ⎝2⋅N⎠⎥
# ⎢                              ⎥
# ⎢         ⎛ π ⎞        ⎛ π ⎞   ⎥
# ⎢1.0⋅ⅈ⋅sin⎜───⎟     cos⎜───⎟   ⎥
# ⎣         ⎝2⋅N⎠        ⎝2⋅N⎠   ⎦

# %%
A=Matrix([[ sqrt(n),0],[0,1]])
#A=Matrix([[ cos(n),0],[0,1]])
#A=Matrix([[(n*(1-sign(sin(t)))/2)+(1+sign(sin(t)))/2,0],[0,1]])
#A.subs(t,3*pi/2)
A
# Out:
# ⎡√n  0⎤
# ⎢     ⎥
# ⎣0   1⎦

# %%
jones1= Matrix([0,1])
jones0= Matrix([1,0])
jones1
# Out:
# ⎡0⎤
# ⎢ ⎥
# ⎣1⎦

# %%
prob=np.zeros(0)
prob_2=np.zeros(0)
A=A.subs(n,1)
for i in range(1,200):
    B=Matrix([[cos(alpha),sin(alpha)],[-sin(alpha),cos(alpha)]])
    B=B.subs(N,i).evalf()
    Paola=(B*A)**(i-1)
    prob=np.append(prob,(jones1.T)*Paola*B*jones1)
    prob_2=np.append(prob_2,(jones0.T)*Paola*B*jones1)
prob_abs=1-(np.square(prob)+np.square(prob_2))

# %%
prob1=np.zeros(0)
prob1_2=np.zeros(0)

A=Matrix([[ np.sqrt(0.5),0],[0,1]])
for i in range(1,200):
    B=Matrix([[cos(alpha),sin(alpha)],[-sin(alpha),cos(alpha)]])
    B=B.subs(N,i).evalf()
    Paola=(B*A)**(i-1)
    prob1=np.append(prob1,(jones1.T)*Paola*B*jones1)
    prob1_2=np.append(prob1_2,(jones0.T)*Paola*B*jones1)
prob_abs1=1-(np.square(prob1)+np.square(prob1_2))

# %%
prob2=np.zeros(0)
prob2_2=np.zeros(0)

A=Matrix([[ np.sqrt(0.2),0],[0,1]])
for i in range(1,200):
    B=Matrix([[cos(alpha),sin(alpha)],[-sin(alpha),cos(alpha)]])
    B=B.subs(N,i).evalf()
    Paola=(B*A)**(i-1)
    prob2=np.append(prob2,(jones1.T)*Paola*B*jones1)
    prob2_2=np.append(prob2_2,(jones0.T)*Paola*B*jones1)
prob_abs2=1-(np.square(prob2)+np.square(prob2_2))

# %%
prob3=np.zeros(0)
prob3_2=np.zeros(0)

A=Matrix([[ np.sqrt(0.015),0],[0,1]])

for i in range(1,200):
    B=Matrix([[cos(alpha),sin(alpha)],[-sin(alpha),cos(alpha)]])
    B=B.subs(N,i).evalf()
    Paola=(B*A)**(i-1)
    prob3=np.append(prob3,(jones1.T)*Paola*B*jones1)
    prob3_2=np.append(prob3_2,(jones0.T)*Paola*B*jones1)
prob_abs3=1-(np.square(prob3)+np.square(prob3_2))

# %%
prob5=np.zeros(0)
prob5_2=np.zeros(0)

A=Matrix([[ np.sqrt(0.8),0],[0,1]])

for i in range(1,200):
    B=Matrix([[cos(alpha),sin(alpha)],[-sin(alpha),cos(alpha)]])
    B=B.subs(N,i).evalf()
    Paola=(B*A)**(i-1)
    prob5=np.append(prob5,(jones1.T)*Paola*B*jones1)
    prob5_2=np.append(prob5_2,(jones0.T)*Paola*B*jones1)
prob_abs5=1-(np.square(prob5)+np.square(prob5_2))

# %%
prob4=np.zeros(0)
prob4_2=np.zeros(0)

A=Matrix([[ np.sqrt(0.002),0],[0,1]])


for i in range(1,200):
    B=Matrix([[cos(alpha),sin(alpha)],[-sin(alpha),cos(alpha)]])
    B=B.subs(N,i).evalf()
    Paola=(B*A)**(i-1)
    prob4=np.append(prob4,(jones1.T)*Paola*B*jones1)
    prob4_2=np.append(prob4_2,(jones0.T)*Paola*B*jones1)
prob_abs4=1-(np.square(prob4)+np.square(prob4_2))

# %%
N=np.linspace(1,199,199)
plt.plot(N,np.square(np.absolute(prob_2)),label=r'n=$1$')
plt.plot(N,np.square(np.absolute(prob1_2)),label=r'n=$0.5$')
plt.plot(N,np.square(np.absolute(prob2_2)),label=r'n=$0.2$')
plt.plot(N,np.square(np.absolute(prob3_2)),label=r'n=$0.015$')
plt.plot(N,np.square(np.absolute(prob4_2)),label=r'n=$0.002$')
plt.plot(N,np.square(np.absolute(prob5_2)),label=r'n=$0.8$')


plt.xlabel('Numero de Beam Splitters')
plt.ylabel('Probabilidad en D2')
plt.xlim(1,50)
plt.ylim(0,1.2)
plt.xticks(np.arange(1,202,25))
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
N=np.linspace(1,199,199)
plt.plot(N,prob_abs,label=r'n=1')
plt.plot(N,prob_abs1,label=r'n=0.5')
plt.plot(N,prob_abs2,label=r'n=0.2')
plt.plot(N,prob_abs3,label=r'n=0.015')
plt.plot(N,prob_abs4,label=r'n=0.002')
plt.plot(N,prob_abs5,label=r'n=0.8')


plt.xlabel('Numero de Beam Splitters')
plt.ylabel('Probabilidad de ser Absorbido')
plt.xlim(1,50)
plt.ylim(0,1.2)
plt.xticks(np.arange(1,202,25))
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Ahora veamos un caso con un solo tipo de Beam Splitter

# %%
theta=np.pi/4
B=Matrix([[cos(theta),sin(theta)],[-sin(theta),cos(theta)]])
B

# %%
#A=Matrix([[ sqrt(n),0],[0,1]])
A=Matrix([[ cos(n),0],[0,1]])
#A=Matrix([[(n*(1-sign(sin(t)))/2)+(1+sign(sin(t)))/2,0],[0,1]])
#A.subs(t,3*pi/2)
A

# %%
prob=np.zeros(0)
prob_2=np.zeros(0)
A=A.subs(n,np.pi)
for i in range(1,200):
    Paola=(B*A)**(i-1)
    prob=np.append(prob,(jones1.T)*Paola*B*jones1)
    prob_2=np.append(prob_2,(jones0.T)*Paola*B*jones1)
prob_abs=1-(np.square(prob)+np.square(prob_2))

# %%
prob1=np.zeros(0)
prob1_2=np.zeros(0)

A=Matrix([[ cos(np.pi/2),0],[0,1]])
for i in range(1,200):
    Paola=(B*A)**(i-1)
    prob1=np.append(prob1,(jones1.T)*Paola*B*jones1)
    prob1_2=np.append(prob1_2,(jones0.T)*Paola*B*jones1)
prob_abs1=1-(np.square(prob1)+np.square(prob1_2))

# %%
prob2=np.zeros(0)
prob2_2=np.zeros(0)

A=Matrix([[ cos(3*np.pi/5),0],[0,1]])
for i in range(1,200):
    Paola=(B*A)**(i-1)
    prob2=np.append(prob2,(jones1.T)*Paola*B*jones1)
    prob2_2=np.append(prob2_2,(jones0.T)*Paola*B*jones1)
prob_abs2=1-(np.square(prob2)+np.square(prob2_2))

# %%
prob3=np.zeros(0)
prob3_2=np.zeros(0)

A=Matrix([[ np.cos(np.pi/4),0],[0,1]])
for i in range(1,200):
    Paola=(B*A)**(i-1)
    prob3=np.append(prob3,(jones1.T)*Paola*B*jones1)
    prob3_2=np.append(prob3_2,(jones0.T)*Paola*B*jones1)
prob_abs3=1-(np.square(prob3)+np.square(prob3_2))

# %%
prob4=np.zeros(0)
prob4_2=np.zeros(0)

A=Matrix([[ cos(np.pi/10),0],[0,1]])


for i in range(1,200):

    Paola=(B*A)**(i-1)
    prob4=np.append(prob4,(jones1.T)*Paola*B*jones1)
    prob4_2=np.append(prob4_2,(jones0.T)*Paola*B*jones1)
prob_abs4=1-(np.square(prob4)+np.square(prob4_2))

# %%
prob5=np.zeros(0)
prob5_2=np.zeros(0)

A=Matrix([[ cos(np.pi/8),0],[0,1]])

for i in range(1,200):
    Paola=(B*A)**(i-1)
    prob5=np.append(prob5,(jones1.T)*Paola*B*jones1)
    prob5_2=np.append(prob5_2,(jones0.T)*Paola*B*jones1)
prob_abs5=1-(np.square(prob5)+np.square(prob5_2))

# %%
N=np.linspace(1,199,199)
plt.plot(N,np.square(np.absolute(prob)),label=r'n=$\pi$')
plt.plot(N,np.square(np.absolute(prob1)),label=r'n=$\frac{\pi}{2}$')
plt.plot(N,np.square(np.absolute(prob2)),label=r'n=$\frac{3\pi}{5}$')
plt.plot(N,np.square(np.absolute(prob3)),label=r'n=$\frac{\pi}{4}$')
plt.plot(N,np.square(np.absolute(prob4)),label=r'n=$\frac{\pi}{10}$')
plt.plot(N,np.square(np.absolute(prob5)),label=r'n=$\frac{\pi}{8}$')


plt.xlabel('Numero de Beam Splitters')
plt.ylabel('Probabilidad de ser Absorbido')
plt.xlim(1,205)
plt.ylim(0,1.2)
plt.xticks(np.arange(1,202,25))
plt.legend()

# %%
N=np.linspace(1,199,199)
plt.plot(N,prob_abs,label=r'n=$\pi$')
plt.plot(N,prob_abs1,label=r'n=$\frac{\pi}{2}$')
plt.plot(N,prob_abs2,label=r'n=$\frac{3\pi}{5}$')
plt.plot(N,prob_abs3,label=r'n=$\frac{\pi}{4}$')
plt.plot(N,prob_abs4,label=r'n=$\frac{\pi}{10}$')
plt.plot(N,prob_abs5,label=r'n=$\frac{\pi}{8}$')


plt.xlabel('Numero de Beam Splitters')
plt.ylabel('Probabilidad de ser Absorbido')
plt.xlim(1,50)
plt.ylim(0,1.2)
plt.xticks(np.arange(1,202,25))
plt.legend()

# %% [markdown]
# # Al parecer Hiro pensaba en Mach-Zehnder usando Fibra Optica donde los espejos no son necesarios , el resultado es el mismo para N par pero no para N Impar

# %%
M=Matrix([[ 0,1j],[1j,0]])
M

# %%
B=Matrix([[cos(alpha),sin(alpha)],[-sin(alpha),cos(alpha)]])
B

# %%
A=Matrix([[ cos(np.pi),0],[0,1]])

# %%
prob=np.zeros(0)
prob_2=np.zeros(0)

for i in range(1,200):
    B=Matrix([[cos(alpha),1j*sin(alpha)],[1j*sin(alpha),cos(alpha)]])
    B=B.subs(N,i).evalf()
    Paola=(B*A)**(i-1)
    prob=np.append(prob,np.absolute((jones1.T)*Paola*B*jones1))
    prob_2=np.append(prob_2,np.absolute((jones0.T)*Paola*B*jones1))
prob_abs=1-(np.square(prob)+np.square(prob_2))

# %%
prob1=np.zeros(0)
prob1_2=np.zeros(0)

A=Matrix([[ cos(np.pi/2),0],[0,1]])
for i in range(1,200):
    B=Matrix([[cos(alpha),1j*sin(alpha)],[1j*sin(alpha),cos(alpha)]])
    B=B.subs(N,i).evalf()
    Paola=(B*A)**(i-1)
    prob1=np.append(prob1,np.absolute((jones1.T)*Paola*B*jones1))
    prob1_2=np.append(prob1_2,np.absolute((jones0.T)*Paola*B*jones1))
prob_abs1=1-(np.square(prob1)+np.square(prob1_2))

# %%
prob2=np.zeros(0)
prob2_2=np.zeros(0)

A=Matrix([[ cos(3*np.pi/5),0],[0,1]])
for i in range(1,200):
    B=Matrix([[cos(alpha),1j*sin(alpha)],[1j*sin(alpha),cos(alpha)]])
    B=B.subs(N,i).evalf()
    Paola=(B*A)**(i-1)
    prob2=np.append(prob2,np.absolute((jones1.T)*Paola*B*jones1))
    prob2_2=np.append(prob2_2,np.absolute((jones0.T)*Paola*B*jones1))
prob_abs2=1-(np.square(prob2)+np.square(prob2_2))

# %%
prob3=np.zeros(0)
prob3_2=np.zeros(0)

A=Matrix([[ cos(np.pi/4),0],[0,1]])
for i in range(1,200):
    B=Matrix([[cos(alpha),1j*sin(alpha)],[1j*sin(alpha),cos(alpha)]])
    B=B.subs(N,i).evalf()
    Paola=(B*A)**(i-1)
    prob3=np.append(prob3,np.absolute((jones1.T)*Paola*B*jones1))
    prob3_2=np.append(prob3_2,np.absolute((jones0.T)*Paola*B*jones1))
prob_abs3=1-(np.square(prob3)+np.square(prob3_2))

# %%
prob4=np.zeros(0)
prob4_2=np.zeros(0)

A=Matrix([[ cos(np.pi/10),0],[0,1]])


for i in range(1,200):
    B=Matrix([[cos(alpha),1j*sin(alpha)],[1j*sin(alpha),cos(alpha)]])
    B=B.subs(N,i).evalf()
    Paola=(B*A)**(i-1)
    prob4=np.append(prob4,np.absolute((jones1.T)*Paola*B*jones1))
    prob4_2=np.append(prob4_2,np.absolute((jones0.T)*Paola*B*jones1))
prob_abs4=1-(np.square(prob4)+np.square(prob4_2))

# %%
prob5=np.zeros(0)
prob5_2=np.zeros(0)

A=Matrix([[ cos(np.pi/8),0],[0,1]])

for i in range(1,200):
    B=Matrix([[cos(alpha),1j*sin(alpha)],[1j*sin(alpha),cos(alpha)]])
    B=B.subs(N,i).evalf()
    Paola=(B*A)**(i-1)
    prob5=np.append(prob5,np.absolute((jones1.T)*Paola*B*jones1))
    prob5_2=np.append(prob5_2,np.absolute((jones0.T)*Paola*B*jones1))
prob_abs5=1-(np.square(prob5)+np.square(prob5_2))

# %%
N=np.linspace(1,199,199)
plt.plot(N,np.square(np.absolute(prob)),label=r'n=$\pi$')
plt.plot(N,np.square(np.absolute(prob1)),label=r'n=$\frac{\pi}{2}$')
plt.plot(N,np.square(np.absolute(prob2)),label=r'n=$\frac{3\pi}{5}$')
plt.plot(N,np.square(np.absolute(prob3)),label=r'n=$\frac{\pi}{4}$')
plt.plot(N,np.square(np.absolute(prob4)),label=r'n=$\frac{\pi}{10}$')
plt.plot(N,np.square(np.absolute(prob5)),label=r'n=$\frac{\pi}{8}$')


plt.xlabel('Numero de Beam Splitters')
plt.ylabel('Probabilidad en D1')
plt.xlim(1,50)
plt.ylim(0,1.2)
plt.xticks(np.arange(1,202,25))
plt.legend()

# %%
N=np.linspace(1,199,199)
plt.plot(N,prob_abs,label=r'n=$\pi$')
plt.plot(N,prob_abs1,label=r'n=$\frac{\pi}{2}$')
plt.plot(N,prob_abs2,label=r'n=$\frac{3\pi}{5}$')
plt.plot(N,prob_abs3,label=r'n=$\frac{\pi}{4}$')
plt.plot(N,prob_abs4,label=r'n=$\frac{\pi}{10}$')
plt.plot(N,prob_abs5,label=r'n=$\frac{\pi}{8}$')


plt.xlabel('Numero de Beam Splitters')
plt.ylabel('Probabilidad de ser Absorbido')
plt.xlim(1,50)
plt.ylim(0,1.2)
plt.xticks(np.arange(1,202,25))
plt.legend()

# %% [markdown]
# # Por lo que vemos que en el caso de trabajar en bulk de cierta forma se pierde la "magia" de Azuma, que pasa con un solo tipo de BS

# %%
theta=np.pi/4
B=Matrix([[cos(theta),sin(theta)],[-sin(theta),cos(theta)]])
B

# %%
#A=Matrix([[ sqrt(n),0],[0,1]])
A=Matrix([[ cos(np.pi),0],[0,1]])
#A=Matrix([[(n*(1-sign(sin(t)))/2)+(1+sign(sin(t)))/2,0],[0,1]])
#A.subs(t,3*pi/2)
A

# %%
prob=np.zeros(0)
prob_2=np.zeros(0)

for i in range(1,200):

    Paola=(B*M*A)**(i-1)
    prob=np.append(prob,np.absolute((jones1.T)*Paola*B*jones1))
    prob_2=np.append(prob_2,np.absolute((jones0.T)*Paola*B*jones1))
prob_abs=1-(np.square(prob)+np.square(prob_2))

# %%
prob1=np.zeros(0)
prob1_2=np.zeros(0)

A=Matrix([[ cos(np.pi/2),0],[0,1]])
for i in range(1,200):

    Paola=(B*M*A)**(i-1)
    prob1=np.append(prob1,np.absolute((jones1.T)*Paola*B*jones1))
    prob1_2=np.append(prob1_2,np.absolute((jones0.T)*Paola*B*jones1))
prob_abs1=1-(np.square(prob1)+np.square(prob1_2))

# %%
prob2=np.zeros(0)
prob2_2=np.zeros(0)

A=Matrix([[ cos(3*np.pi/5),0],[0,1]])
for i in range(1,200):

    Paola=(B*M*A)**(i-1)
    prob2=np.append(prob2,np.absolute((jones1.T)*Paola*B*jones1))
    prob2_2=np.append(prob2_2,np.absolute((jones0.T)*Paola*B*jones1))
prob_abs2=1-(np.square(prob2)+np.square(prob2_2))

# %%
prob3=np.zeros(0)
prob3_2=np.zeros(0)

A=Matrix([[ cos(np.pi/4),0],[0,1]])
for i in range(1,200):

    Paola=(B*M*A)**(i-1)
    prob3=np.append(prob3,np.absolute((jones1.T)*Paola*B*jones1))
    prob3_2=np.append(prob3_2,np.absolute((jones0.T)*Paola*B*jones1))
prob_abs3=1-(np.square(prob3)+np.square(prob3_2))

# %%
prob4=np.zeros(0)
prob4_2=np.zeros(0)

A=Matrix([[ cos(np.pi/10),0],[0,1]])


for i in range(1,200):

    Paola=(B*M*A)**(i-1)
    prob4=np.append(prob4,np.absolute((jones1.T)*Paola*B*jones1))
    prob4_2=np.append(prob4_2,np.absolute((jones0.T)*Paola*B*jones1))
prob_abs4=1-(np.square(prob4)+np.square(prob4_2))

# %%
prob5=np.zeros(0)
prob5_2=np.zeros(0)

A=Matrix([[ cos(np.pi/8),0],[0,1]])

for i in range(1,200):

    Paola=(B*M*A)**(i-1)
    prob5=np.append(prob5,np.absolute((jones1.T)*Paola*B*jones1))
    prob5_2=np.append(prob5_2,np.absolute((jones0.T)*Paola*B*jones1))
prob_abs5=1-(np.square(prob5)+np.square(prob5_2))

# %%
N=np.linspace(1,199,199)
plt.plot(N,np.square(np.absolute(prob)),label=r'n=$\pi$')
plt.plot(N,np.square(np.absolute(prob1)),label=r'n=$\frac{\pi}{2}$')
plt.plot(N,np.square(np.absolute(prob2)),label=r'n=$\frac{3\pi}{5}$')
plt.plot(N,np.square(np.absolute(prob3)),label=r'n=$\frac{\pi}{4}$')
plt.plot(N,np.square(np.absolute(prob4)),label=r'n=$\frac{\pi}{10}$')
plt.plot(N,np.square(np.absolute(prob5)),label=r'n=$\frac{\pi}{8}$')


plt.xlabel('Numero de Beam Splitters')
plt.ylabel('Probabilidad en D2')
plt.xlim(1,50)
plt.ylim(0,1.2)
plt.xticks(np.arange(1,202,25))
plt.legend()

# %%
N=np.linspace(1,199,199)
plt.plot(N,prob_abs,label=r'n=$\pi$')
plt.plot(N,prob_abs1,label=r'n=$\frac{\pi}{2}$')
plt.plot(N,prob_abs2,label=r'n=$\frac{3\pi}{5}$')
plt.plot(N,prob_abs3,label=r'n=$\frac{\pi}{4}$')
plt.plot(N,prob_abs4,label=r'n=$\frac{\pi}{10}$')
plt.plot(N,prob_abs5,label=r'n=$\frac{\pi}{8}$')


plt.xlabel('Numero de Beam Splitters')
plt.ylabel('Probabilidad de ser Absorbido')
plt.xlim(1,50)
plt.ylim(0,1.2)
plt.xticks(np.arange(1,202,25))
plt.legend()
